# %%
#Exercici 1_Descarrega el data set Airlines Delay: Airline on-time statistics and delay causes i 
#carrega’l a un pandas Dataframe. Explora les dades que conté, i queda’t únicament amb les columnes 
#que consideris rellevants

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

Airlines_Delay = pd.read_csv(r'C:\\Users\\mio\\Documents\\IT ACADEMY\\3.5_Pandas\\data\\finaldata\\DelayedFlights.csv')

# %%
Airlines_Delay.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime',
#        'CRSDepTime', 'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum',
#        'TailNum', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
Airlines_Delay.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
# 3           4  2008      1           3          4   1829.0        1755
# 4           5  2008      1           3          4   1940.0        1915
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  Cancelled CancellationCode  \
# 0   2211.0        2225            WN  ...          0                N
# 1   1002.0        1000            WN  ...          0                N
# 2    804.0         750            WN  ...          0                N
# 3   1959.0        1925            WN  ...          0                N
# 4   2121.0        2110            WN  ...          0                N
#
#    Diverted  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# ...

# %%
#per visualizar menys columnes
Airlines_Delay.drop(columns=['TaxiIn', 'TaxiOut',
       'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
       'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],axis=1)
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0                 0  2008      1           3          4   2003.0        1955
# 1                 1  2008      1           3          4    754.0         735
# 2                 2  2008      1           3          4    628.0         620
# 3                 4  2008      1           3          4   1829.0        1755
# 4                 5  2008      1           3          4   1940.0        1915
# ...             ...   ...    ...         ...        ...      ...         ...
# 1936753     7009710  2008     12          13          6   1250.0        1220
# 1936754     7009717  2008     12          13          6    657.0         600
# 1936755     7009718  2008     12          13          6   1007.0         847
# 1936756     7009726  2008     12          13          6   1251.0        1240
# 1936757     7009727  2008     12          13          6   1110.0        1103
#
# ...

# %%
#per un fitxer amb menys columnes
Airlines_Delay_reduced = Airlines_Delay[['Unnamed: 0', 'Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime',
       'CRSDepTime', 'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum',
       'TailNum', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
       'DepDelay', 'Origin', 'Dest', 'Distance']]
Airlines_Delay_reduced.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime',
#        'CRSDepTime', 'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum',
#        'TailNum', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance'],
#       dtype='object')

# %%
#Exercici 2
#Fes un informe complet del data set:.

# %%
#Resumeix estadísticament les columnes d’interès
Airlines_Delay.describe().round(1)
# Out:
#        Unnamed: 0       Year      Month  DayofMonth  DayOfWeek    DepTime  \
# count   1936758.0  1936758.0  1936758.0   1936758.0  1936758.0  1936758.0
# mean    3341651.2     2008.0        6.1        15.8        4.0     1518.5
# std     2066065.0        0.0        3.5         8.8        2.0      450.5
# min           0.0     2008.0        1.0         1.0        1.0        1.0
# 25%     1517452.5     2008.0        3.0         8.0        2.0     1203.0
# 50%     3242558.0     2008.0        6.0        16.0        4.0     1545.0
# 75%     4972466.8     2008.0        9.0        23.0        6.0     1900.0
# max     7009727.0     2008.0       12.0        31.0        7.0     2400.0
#
#        CRSDepTime    ArrTime  CRSArrTime  FlightNum  ...   Distance  \
# count   1936758.0  1929648.0   1936758.0  1936758.0  ...  1936758.0
# mean       1467.5     1610.1      1634.2     2184.3  ...      765.7
# std         424.8      548.2       464.6     1944.7  ...      574.5
# ...

# %%
Airlines_Delay.describe(include = "all")
# Out:
#           Unnamed: 0       Year         Month    DayofMonth     DayOfWeek  \
# count   1.936758e+06  1936758.0  1.936758e+06  1.936758e+06  1.936758e+06
# unique           NaN        NaN           NaN           NaN           NaN
# top              NaN        NaN           NaN           NaN           NaN
# freq             NaN        NaN           NaN           NaN           NaN
# mean    3.341651e+06     2008.0  6.111106e+00  1.575347e+01  3.984827e+00
# std     2.066065e+06        0.0  3.482546e+00  8.776272e+00  1.995966e+00
# min     0.000000e+00     2008.0  1.000000e+00  1.000000e+00  1.000000e+00
# 25%     1.517452e+06     2008.0  3.000000e+00  8.000000e+00  2.000000e+00
# 50%     3.242558e+06     2008.0  6.000000e+00  1.600000e+01  4.000000e+00
# 75%     4.972467e+06     2008.0  9.000000e+00  2.300000e+01  6.000000e+00
# max     7.009727e+06     2008.0  1.200000e+01  3.100000e+01  7.000000e+00
#
#              DepTime    CRSDepTime       ArrTime    CRSArrTime UniqueCarrier  \
# ...

# %%
Airlines_Delay.isnull()
# Out:
#          Unnamed: 0   Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0             False  False  False       False      False    False       False
# 1             False  False  False       False      False    False       False
# 2             False  False  False       False      False    False       False
# 3             False  False  False       False      False    False       False
# 4             False  False  False       False      False    False       False
# ...             ...    ...    ...         ...        ...      ...         ...
# 1936753       False  False  False       False      False    False       False
# 1936754       False  False  False       False      False    False       False
# 1936755       False  False  False       False      False    False       False
# 1936756       False  False  False       False      False    False       False
# 1936757       False  False  False       False      False    False       False
#
# ...

# %%
#Troba quantes dades faltants hi ha per columna
Airlines_Delay.isnull().sum()
# Out:
# Unnamed: 0                0
# Year                      0
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                   0
# CRSDepTime                0
# ArrTime                7110
# CRSArrTime                0
# UniqueCarrier             0
# FlightNum                 0
# TailNum                   5
# ActualElapsedTime      8387
# CRSElapsedTime          198
# AirTime                8387
# ArrDelay               8387
# DepDelay                  0
# Origin                    0
# Dest                      0
# Distance                  0
# TaxiIn                 7110
# TaxiOut                 455
# Cancelled                 0
# CancellationCode          0
# Diverted                  0
# CarrierDelay         689270
# WeatherDelay         689270
# NASDelay             689270
# SecurityDelay        689270
# LateAircraftDelay    689270
# AvFlightSpeed          8387
# Flight_status             0
# dtype: int64

# %%
#Troba quantes dades faltants hi ha per columna....percentatge
(Airlines_Delay.isnull().sum())*100/len(Airlines_Delay)
# Out:
# Unnamed: 0            0.000000
# Year                  0.000000
# Month                 0.000000
# DayofMonth            0.000000
# DayOfWeek             0.000000
# DepTime               0.000000
# CRSDepTime            0.000000
# ArrTime               0.367108
# CRSArrTime            0.000000
# UniqueCarrier         0.000000
# FlightNum             0.000000
# TailNum               0.000258
# ActualElapsedTime     0.433043
# CRSElapsedTime        0.010223
# AirTime               0.433043
# ArrDelay              0.433043
# DepDelay              0.000000
# Origin                0.000000
# Dest                  0.000000
# Distance              0.000000
# TaxiIn                0.367108
# TaxiOut               0.023493
# Cancelled             0.000000
# CancellationCode      0.000000
# Diverted              0.000000
# CarrierDelay         35.588855
# WeatherDelay         35.588855
# NASDelay             35.588855
# SecurityDelay        35.588855
# LateAircraftDelay    35.588855
# ...

# %%
Airlines_Delay['ArrDelay'].isnull().sum()
# Out:
# 8387

# %%
(Airlines_Delay.notnull().sum())*100/len(Airlines_Delay)
# Out:
# Unnamed: 0           100.000000
# Year                 100.000000
# Month                100.000000
# DayofMonth           100.000000
# DayOfWeek            100.000000
# DepTime              100.000000
# CRSDepTime           100.000000
# ArrTime               99.632892
# CRSArrTime           100.000000
# UniqueCarrier        100.000000
# FlightNum            100.000000
# TailNum               99.999742
# ActualElapsedTime     99.566957
# CRSElapsedTime        99.989777
# AirTime               99.566957
# ArrDelay              99.566957
# DepDelay             100.000000
# Origin               100.000000
# Dest                 100.000000
# Distance             100.000000
# TaxiIn                99.632892
# TaxiOut               99.976507
# Cancelled            100.000000
# CancellationCode     100.000000
# Diverted             100.000000
# CarrierDelay          64.411145
# WeatherDelay          64.411145
# NASDelay              64.411145
# SecurityDelay         64.411145
# ...

# %%
ArrDelay_Clean = Airlines_Delay.fillna(Airlines_Delay['ArrDelay'].mean())
ArrDelay_Clean.isnull().sum()
# Out:
# Unnamed: 0           0
# Year                 0
# Month                0
# DayofMonth           0
# DayOfWeek            0
# DepTime              0
# CRSDepTime           0
# ArrTime              0
# CRSArrTime           0
# UniqueCarrier        0
# FlightNum            0
# TailNum              0
# ActualElapsedTime    0
# CRSElapsedTime       0
# AirTime              0
# ArrDelay             0
# DepDelay             0
# Origin               0
# Dest                 0
# Distance             0
# TaxiIn               0
# TaxiOut              0
# Cancelled            0
# CancellationCode     0
# Diverted             0
# CarrierDelay         0
# WeatherDelay         0
# NASDelay             0
# SecurityDelay        0
# LateAircraftDelay    0
# dtype: int64

# %% [markdown]
# ### TBC
# #Airlines_Delay_Clean = Airlines_Delay.fillna(Airlines_Delay.mean())
# #Airlines_Delay_Clean.isnull().sum()

# %%
#Crea columnes noves (velocitat mitjana del vol)
Airlines_Delay[['DepTime','ArrTime','ArrDelay','AirTime','ActualElapsedTime', 'CRSElapsedTime','TaxiIn','TaxiOut']]
# Out:
#          DepTime  ArrTime  ArrDelay  AirTime  ActualElapsedTime  \
# 0         2003.0   2211.0     -14.0    116.0              128.0
# 1          754.0   1002.0       2.0    113.0              128.0
# 2          628.0    804.0      14.0     76.0               96.0
# 3         1829.0   1959.0      34.0     77.0               90.0
# 4         1940.0   2121.0      11.0     87.0              101.0
# ...          ...      ...       ...      ...                ...
# 1936753   1250.0   1617.0      25.0    120.0              147.0
# 1936754    657.0    904.0      75.0     78.0              127.0
# 1936755   1007.0   1149.0      99.0    122.0              162.0
# 1936756   1251.0   1446.0       9.0     89.0              115.0
# 1936757   1110.0   1413.0      -5.0    104.0              123.0
#
#          CRSElapsedTime  TaxiIn  TaxiOut
# 0                 150.0     4.0      8.0
# 1                 145.0     5.0     10.0
# 2                  90.0     3.0     17.0
# ...

# %%
#velocitat mitjana del vol='AvFlightSpeed'
Airlines_Delay['AvFlightSpeed'] = Airlines_Delay['Distance'] / Airlines_Delay['AirTime'] * 60
Airlines_Delay[['Distance','AirTime','AvFlightSpeed']]
# Out:
#          Distance  AirTime  AvFlightSpeed
# 0             810    116.0     418.965517
# 1             810    113.0     430.088496
# 2             515     76.0     406.578947
# 3             515     77.0     401.298701
# 4             688     87.0     474.482759
# ...           ...      ...            ...
# 1936753       906    120.0     453.000000
# 1936754       481     78.0     370.000000
# 1936755       689    122.0     338.852459
# 1936756       533     89.0     359.325843
# 1936757       874    104.0     504.230769
#
# [1936758 rows x 3 columns]

# %%
#Crea columnes noves (si ha arribat tard o no)
def Flight_status_function(x):
    if x > 0:
        return "Late"
    else:
        return "On time"
Airlines_Delay["Flight_status"] = Airlines_Delay["ArrDelay"].apply(Flight_status_function)
Airlines_Delay[['DepTime','ArrDelay','Flight_status']]
# Out:
#          DepTime  ArrDelay Flight_status
# 0         2003.0     -14.0       On time
# 1          754.0       2.0          Late
# 2          628.0      14.0          Late
# 3         1829.0      34.0          Late
# 4         1940.0      11.0          Late
# ...          ...       ...           ...
# 1936753   1250.0      25.0          Late
# 1936754    657.0      75.0          Late
# 1936755   1007.0      99.0          Late
# 1936756   1251.0       9.0          Late
# 1936757   1110.0      -5.0       On time
#
# [1936758 rows x 3 columns]

# %%
#Taula de les aerolínies amb més endarreriments acumulats

# %%
#Seleccioanr only 'Late' flight
Airlines_Delay_Late = Airlines_Delay[Airlines_Delay['Flight_status']=='Late']
print(Airlines_Delay_Late)
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 1                 1  2008      1           3          4    754.0         735
# 2                 2  2008      1           3          4    628.0         620
# 3                 4  2008      1           3          4   1829.0        1755
# 4                 5  2008      1           3          4   1940.0        1915
# 5                 6  2008      1           3          4   1937.0        1830
# ...             ...   ...    ...         ...        ...      ...         ...
# 1936752     7009709  2008     12          13          6   1552.0        1520
# 1936753     7009710  2008     12          13          6   1250.0        1220
# 1936754     7009717  2008     12          13          6    657.0         600
# 1936755     7009718  2008     12          13          6   1007.0         847
# 1936756     7009726  2008     12          13          6   1251.0        1240
#
# ...

# %%
#Seleccionar columnas para tabla reducida
Worst_Airlines_Delay = Airlines_Delay_Late[['UniqueCarrier','ArrDelay','Flight_status']]
print(Worst_Airlines_Delay)
# Out:
#         UniqueCarrier  ArrDelay Flight_status
# 1                  WN       2.0          Late
# 2                  WN      14.0          Late
# 3                  WN      34.0          Late
# 4                  WN      11.0          Late
# 5                  WN      57.0          Late
# ...               ...       ...           ...
# 1936752            DL      17.0          Late
# 1936753            DL      25.0          Late
# 1936754            DL      75.0          Late
# 1936755            DL      99.0          Late
# 1936756            DL       9.0          Late
#
# [1723415 rows x 3 columns]

# %%
#Count endarreriments acumulats per aerolínies
Result=Worst_Airlines_Delay.set_index(['UniqueCarrier','Flight_status']).count(level='UniqueCarrier')
print(Result)
Result.plot.bar()
# Out:
#                ArrDelay
# UniqueCarrier
# 9E                46896
# AA               172197
# AQ                  654
# AS                34179
# B6                48177
# CO                83646
# DL               100923
# EV                75170
# F9                25708
# FL                65008
# HA                 7199
# MQ               130647
# NW                72395
# OH                49104
# OO               121942
# UA               123989
# US                83262
# WN               324717
# XE                94313
# YV                63289
# <AxesSubplot:xlabel='UniqueCarrier'>

# %%
#Quins són els vols més llargs?
max_value = Airlines_Delay[['Distance']].max()
print(max_value)
# Out:
# Distance    4962
# dtype: int64

# %%
#Index del vol més llarg?
max_index = Airlines_Delay[['Distance']].idxmax()
print(max_index)
# Out:
# Distance    173177
# dtype: int64

# %%
#Quins són els vols més endarrerits?
max_value = Airlines_Delay[['ArrDelay']].max()
print(max_value)
# Out:
# ArrDelay    2461.0
# dtype: float64

# %%
#Index del vol més endarrerit?
max_index = Airlines_Delay[['ArrDelay']].idxmax()
print(max_index)
# Out:
# ArrDelay    322516
# dtype: int64

# %% [markdown]
# ### 2461h must be a mistaken value!

# %%
Airlines_Delay.iloc[322515:322520,15]
# Out:
# 322515      10.0
# 322516    2461.0
# 322517     256.0
# 322518      43.0
# 322519       0.0
# Name: ArrDelay, dtype: float64
